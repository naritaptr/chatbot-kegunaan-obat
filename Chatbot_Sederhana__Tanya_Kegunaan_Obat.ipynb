# %% [markdown]
# ## Proses 1 (Import Library and Reading the Corpus)

# %%
import random
import nltk
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
f=open('/content/kegunaan_obat.txt', 'r', errors= 'ignore')
raw_doc=f.read()
raw_doc=raw_doc.lower() 
nltk.download('punkt') 
nltk.download('wordnet')
sent_tokens = nltk.sent_tokenize(raw_doc)
word_tokens = nltk.word_tokenize(raw_doc)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#dataset file
#https://drive.google.com/file/d/1T8iCa8RGScYo5Fe3YoD8G8z7DT-Luztb/view?usp=sharing

# %% [markdown]
# # Proses 2 (Tokenization)

# %%
# Tokenization
sentence_list = nltk.sent_tokenize(raw_doc) 

# Print the list of sentences
print(sentence_list)
# Out:
# ['parasetamol digunakan untuk mengobati banyak kondisi, seperti sakit kepala, nyeri otot, radang sendi, sakit punggung, sakit gigi, dan demam.', 'cetirizine adalah obat yang digunakan untuk mengatasi kulit kemerahan disertai gatal-gatal, dan pilek yang disebabkan karena alergi.', 'domperidone digunakan untuk mengatasi mual dan muntah, serta gangguan pergerakan usus.', 'antasida secara umum digunakan untuk menetralkan asam lambung pada penderita maag.', 'amoksisilin secara umum adalah obat antibiotik untuk mengobati infeksi bakteri\nambroxol digunakan untuk pengobatan pada pasien dengan penyakit-penyakit pada saluran pernapasan dimana terjadi produksi lendir atau dahak yang berlebihan.', 'asam mefenamat secara umum adalah obat nyeri.', 'simvastatin digunakan untuk menurunkan kolesterol dan trigliserida dalam darah.', 'amlodipine digunakan untuk mengobati darah tinggi.', 'allopurinol digunakan untuk mengobati asam urat berlebih.', 'metformin digunakan untuk mengobati diabetes.', 'vitam
# ...

# %% [markdown]
# ## Proses 3 (Bot Response)

# %%
#a function to return a random greeting response to a users greeting
def greeting_response(text):
    text = text.lower()
    
    #Bots greeting respone
    bot_greetings = ['halo','hai','yuhuu','*eyebrows up*']
    
    #Users greeting
    user_greetings = ['Haloo','Eh iyaa Haii','Hai','greetings','wassup']
    
    for word in text.split():
        if word in user_greetings:
            return random.choice(bot_greetings)
        
    #Random response to greeting
    def gratitude_response(text):
        text=text.lower()

# %% [markdown]
# ## Sorting List

# %%
 def index_sort(list_var):
    length = len(list_var)
    list_index = list(range(0, length))
    
    x = list_var        
    for i in range(length):
        for j in range(length):
            if x[list_index[i]] > x[list_index[j]]:
                #swap
                temp = list_index[i]
                list_index[i] = list_index[j]
                list_index[j] = temp
                
    return list_index

# %% [markdown]
# ## Chatbot Respon Menggunakan Cosine Similarity

# %%
# Creat Bots Response
def bot_response(user_input):
    user_input=user_input.lower()
    sentence_list.append(user_input)
    bot_response= ''
    cm=CountVectorizer().fit_transform(sentence_list)
    similarity_scores=cosine_similarity(cm[-1],cm)
    similarity_scores_list=similarity_scores.flatten()
    index=index_sort(similarity_scores_list)
    index=index[1:]
    response_flag=0
    
    j=0
    for i in range(len(index)):
        if similarity_scores_list[index[i]]>0.0:
            bot_response=bot_response+' '+sentence_list[index[i]]
            response_flag=1
            j=j+1
        if j>2:
            break

        if response_flag==0:
            bot_response=bot_response+" "+"Maaf, saya tidak mengerti, keyword salah"

        sentence_list.remove(user_input) 

        return bot_response

# %% [markdown]
# # Proses 4 (End Process, Making chat box)

# %%
#Start Chat
print("Apoteker Bot: Mau bertanya tentang obat apa? (Ketik nama obat)")
print("Keyword:  \n1. paracetamol\n 2. cetirizine\n 3. domperidon\n 4. antasida\n 5. amoksisilin\n 6. ambroxol\n 7. asam mefenamat\n 8. simvastatin\n 9. amlodipin\n 10. allopurinol\n 11. metformin\n 12. vitamin c\n 13. omeprazole\n 14. pantoprazol\n 15. salbutamol\n")

exit_list=['exit','bye','keluar','quit', 'sampai jumpa']

while(True):
    user_input=input()
    if user_input.lower() in exit_list:
        print('Apoteker Bot: Bye Sampai jumpa lagi')
        break
    else:
        if greeting_response(user_input)!= None:
            print('Apoteker Bot: '+ greeting_response(user_input))
        else:
            print('Apoteker Bot: '+ bot_response(user_input))
# Out:
# Apoteker Bot: Mau bertanya tentang obat apa? (Ketik nama obat)
# Keyword:
# 1. paracetamol
#  2. cetirizine
#  3. domperidon
#  4. antasida
#  5. amoksisilin
#  6. ambroxol
#  7. asam mefenamat
#  8. simvastatin
#  9. amlodipin
#  10. allopurinol
#  11. metformin
#  12. vitamin c
#  13. omeprazole
#  14. pantoprazol
#  15. salbutamol
#
# antasida
# Apoteker Bot:  antasida secara umum digunakan untuk menetralkan asam lambung pada penderita maag.
# vitamin c
# Apoteker Bot:  vitamin c secara umum adalah obat suplemen, vitamin.
# allopurinol
# Apoteker Bot:  allopurinol digunakan untuk mengobati asam urat berlebih.
# exit
# Apoteker Bot: Bye Sampai jumpa lagi
